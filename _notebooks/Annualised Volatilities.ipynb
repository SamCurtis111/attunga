# %% [markdown]
# # Annualised Volatilities Report
# > Updated volatilities
# - toc: true
# - badges: false
# - comments: true
# - categories: [jupyter]
# - image: images/chart-preview.png

# %%
from pathlib import Path

import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)    # prevent dfs from being truncated

# %%
## IMPORT DATA ##
data_path = Path("C:/Users/SamCurtis/AppData/Local/bipy/28095931/projects/02f1bf62483a4d82b93898b71672e018") / ("tableau_vols.xlsx")
raw_baseload = pd.read_excel(data_path, sheet_name='Baseload')
raw_caps = pd.read_excel(data_path, sheet_name='Caps')
raw_strips = pd.read_excel(data_path, sheet_name='Strips')


last_update_path = Path("C:/Users/SamCurtis/AppData/Local/bipy/28095931/projects/02f1bf62483a4d82b93898b71672e018") / ("volatility_data.xlsx")
last_updated = pd.read_excel(last_update_path, sheet_name='last_updated')
last_updated = last_updated['updated'][0]

# %%
print('Last Updated: ', last_updated)
# Out:
# Last Updated:  2021-03-03 17:04:56

# %% [markdown]
# ## Baseload Contracts

# %%
baseload_pivot = pd.pivot_table(raw_baseload, index=["state", "year","quater"])
baseload_pivot = baseload_pivot.iloc[:,1:]
baseload_pivot
# Out:
#                    annual  monthly   qtrly  weekly
# state year quater
# NSW   2021 1       0.2772   0.4816  0.4630  0.0795
#            2       0.1727   0.2151  0.1830  0.2940
#            3       0.1803   0.2390  0.1932  0.2480
#            4       0.1826   0.2316  0.1896  0.2216
#       2022 1       0.1831   0.3440  0.2470  0.3338
#            2       0.1553   0.2025  0.1773  0.2453
#            3       0.1445   0.1592  0.1490  0.1567
#            4       0.1429   0.1922  0.1568  0.2926
#       2023 1       0.1537   0.2815  0.2071  0.2277
#            2       0.1738   0.2332  0.1526  0.3413
#            3          NaN   0.2307  0.1670  0.2373
#            4          NaN   0.2138  0.1633  0.2925
#       2024 1          NaN   0.1968  0.1335  0.0893
#            2          NaN   0.1556  0.1213  0.1032
#            3          NaN   0.0403  0.0413  0.0000
#            4          NaN   0.0235  0.0362  0.0000
# QLD   2021 1       0.2079   0.2814  0.3026  0.2235
#            2       0.1769   0.1036  0.1425  0.1073
#            3       0.1829   0.1661  0.1645  0.1853
#            4       0.1859   0.2059  0.1848  0.2403
#       2022 1       0.1519   0.2341  0.1800  0.3004
#            2       0.1461   0.2111  0.1608  0.2555
#            3       0.1430   0.1701  0.1420  0.2033
#            4       0.1446   0.1884  0.1475  0.2233
#       2023 1       0.1488   0.2726  0.1801  0.3662
#            2       0.1689   0.2400  0.1599  0.3242
#            3          NaN   0.2268  0.1475  0.2551
#            4          NaN   0.2886  0.1841  0.5098
#       2024 1          NaN   0.1820  0.1317  0.0864
#            2          NaN   0.1462  0.1140  0.0869
#            3          NaN   0.1415  0.0948  0.0860
#            4          NaN   0.1559  0.0994  0.0864
# SA    2021 1       0.2936   0.6853  0.4983  0.4503
#            2       0.1970   0.2850  0.1979  0.0866
#            3       0.1607   0.1766  0.1423  0.1046
#            4       0.1732   0.2402  0.1656  0.3005
#       2022 1       0.1842   0.2489  0.1917  0.0284
#            2       0.1669   0.2613  0.1688  0.0000
#            3       0.1731   0.2319  0.1448  0.1905
#            4       0.1631   0.2217  0.1896  0.1012
#       2023 1       0.1767   0.3240  0.2249  0.0323
#            2       0.2498   0.3756  0.2319  0.0326
#            3          NaN   0.2959  0.1920  0.0330
#            4          NaN   0.2958  0.1995  0.0318
#       2024 1          NaN   0.2367  0.1885  0.0000
#            2          NaN   0.2630  0.3809  0.0000
#            3          NaN   0.1733  0.3404  0.0000
#            4          NaN   0.4327  0.2829  0.0000
# VIC   2021 1       0.3686   0.9504  0.6319  0.2614
#            2       0.2292   0.4213  0.2810  0.4247
#            3       0.2050   0.3145  0.2219  0.3205
#            4       0.2159   0.3399  0.2344  0.4185
#       2022 1       0.2310   0.4339  0.2960  0.4703
#            2       0.2150   0.4341  0.2786  0.6851
#            3       0.2046   0.3997  0.2552  0.5121
#            4       0.2334   0.5633  0.3507  0.5329
#       2023 1       0.1869   0.4110  0.2761  0.3236
#            2       0.1655   0.3406  0.2069  0.2819
#            3          NaN   0.3486  0.2059  0.2468
#            4          NaN   0.4243  0.2516  0.4680
#       2024 1          NaN   0.3027  0.2030  0.0000
#            2          NaN   0.1994  0.1227  0.0039
#            3          NaN   0.1852  0.1123  0.0000
#            4          NaN   0.2008  0.1225  0.0000

# %% [markdown]
# ## Caps

# %%
cap_pivot = pd.pivot_table(raw_caps, index=["state", "year","quater"])
cap_pivot = cap_pivot.iloc[:,1:]
cap_pivot
# Out:
#                    annual  monthly   qtrly  weekly
# state year quater
# NSW   2021 1       0.8250   2.0127  1.5102  1.5567
#            2       0.4208   0.9586  0.6203  0.9759
#            3          NaN   0.3981  0.2766  0.3872
# QLD   2021 1       0.6049   1.4364  1.0978  1.2608
#            2       0.5156   1.1178  0.7298  2.1400
#            3          NaN   0.8506  0.6833  1.1542
# SA    2021 1       0.7119   2.0921  1.3304  0.5584
#            2       0.3279   0.8203  0.4867  0.0000
#            3          NaN   0.6226  0.3684  0.0000
# VIC   2021 1       0.9565   2.6759  1.7572  2.0980
#            2       0.3575   0.9935  0.6172  0.4140
#            3          NaN   0.6819  0.5728  0.4934

# %% [markdown]
# ## Strips

# %%
strips_pivot = pd.pivot_table(raw_strips, index=["state", "year","prod_type"])
strips_pivot = strips_pivot.iloc[:,1:]
strips_pivot
# Out:
#                       annual  monthly   qtrly  quater  weekly
# state year prod_type
# NSW   2021 Cal        0.1777   0.2526  0.2324       4  0.2317
#       2022 Cal        0.1349   0.1972  0.1611       4  0.2390
#            Fin        0.1545   0.2270  0.1850       2  0.2435
#       2023 Cal           NaN   0.2306  0.1533       4  0.2707
#            Fin        0.1231   0.2066  0.1462       2  0.2365
#       2024 Cal           NaN   0.0891  0.0674       4  0.0516
#            Fin           NaN   0.1751  0.1204       2  0.1735
# QLD   2021 Cal        0.1665   0.1563  0.1749       4  0.1721
#       2022 Cal        0.1287   0.1781  0.1435       4  0.2293
#            Fin        0.1456   0.1859  0.1574       2  0.2368
#       2023 Cal           NaN   0.2295  0.1523       4  0.3932
#            Fin        0.1288   0.1959  0.1423       2  0.2881
#       2024 Fin           NaN   0.1672  0.1161       2  0.2379
# SA    2021 Cal        0.1550   0.2748  0.2031       4  0.1429
#       2022 Cal        0.1383   0.2164  0.1454       4  0.0430
#            Fin        0.1287   0.1873  0.1332       2  0.0722
#       2023 Cal           NaN   0.2949  0.1877       4  0.0324
#            Fin        0.1419   0.2552  0.1645       2  0.0541
#       2024 Cal           NaN   0.2586  0.2440       4  0.0000
#            Fin           NaN   0.2553  0.1968       2  0.0147
# VIC   2021 Cal        0.2150   0.4262  0.2919       4  0.3119
#       2022 Cal        0.1893   0.3832  0.2479       4  0.5096
#            Fin        0.1954   0.3509  0.2364       2  0.4450
#       2023 Cal           NaN   0.3671  0.2238       4  0.3108
#            Fin        0.1576   0.3518  0.2214       2  0.3800
#       2024 Cal           NaN   0.2128  0.1348       4  0.0000
#            Fin           NaN   0.2695  0.1662       2  0.1559
