# %% [markdown]
# # Annualised Volatilities Report
# > Updated volatilities
# - toc: true
# - badges: false
# - comments: true
# - categories: [jupyter]
# - image: images/chart-preview.png

# %%
from pathlib import Path

import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)    # prevent dfs from being truncated

# %%
## IMPORT DATA ##
data_path = Path("C:/Users/SamCurtis/AppData/Local/bipy/28095931/projects/02f1bf62483a4d82b93898b71672e018") / ("tableau_vols.xlsx")
raw_baseload = pd.read_excel(data_path, sheet_name='Baseload')
raw_caps = pd.read_excel(data_path, sheet_name='Caps')
raw_strips = pd.read_excel(data_path, sheet_name='Strips')


last_update_path = Path("C:/Users/SamCurtis/AppData/Local/bipy/28095931/projects/02f1bf62483a4d82b93898b71672e018") / ("volatility_data.xlsx")
last_updated = pd.read_excel(last_update_path, sheet_name='last_updated')
last_updated = last_updated['updated'][0]

# %%
print('Last Updated: ', last_updated)
# Out:
# Last Updated:  2021-02-24 21:55:24

# %% [markdown]
# ## Baseload Contracts

# %%
baseload_pivot = pd.pivot_table(raw_baseload, index=["state", "year","quater"])
baseload_pivot = baseload_pivot.iloc[:,1:]
baseload_pivot
# Out:
#                    annual  monthly   qtrly  weekly
# state year quater
# NSW   2021 1       0.2770   0.6748  0.4633  0.1340
#            2       0.1706   0.2141  0.1802  0.3391
#            3       0.1791   0.2449  0.1920  0.2507
#            4       0.1812   0.2422  0.1870  0.2109
#       2022 1       0.1810   0.3549  0.2420  0.3429
#            2       0.1534   0.1921  0.1707  0.2087
#            3       0.1438   0.1688  0.1472  0.2006
#            4       0.1399   0.1754  0.1466  0.2945
#       2023 1       0.1519   0.3038  0.2015  0.2598
#            2       0.1709   0.2124  0.1386  0.3237
#            3          NaN   0.2302  0.1620  0.3238
#            4          NaN   0.2128  0.1545  0.2442
#       2024 1          NaN   0.2046  0.1336  0.1618
#            2          NaN   0.1634  0.1245  0.2508
#            3          NaN   0.0403  0.0413  0.0536
#            4          NaN   0.0235  0.0362  0.0000
# QLD   2021 1       0.2063   0.3630  0.3006  0.3084
#            2       0.1768   0.1125  0.1509  0.1048
#            3       0.1819   0.1604  0.1638  0.2575
#            4       0.1846   0.1995  0.1840  0.2799
#       2022 1       0.1494   0.2270  0.1751  0.3666
#            2       0.1435   0.1934  0.1525  0.2889
#            3       0.1414   0.1534  0.1366  0.2619
#            4       0.1434   0.1805  0.1432  0.3079
#       2023 1       0.1463   0.2576  0.1726  0.5065
#            2       0.1665   0.2194  0.1504  0.4239
#            3          NaN   0.2140  0.1424  0.3933
#            4          NaN   0.2547  0.1657  0.5094
#       2024 1          NaN   0.1734  0.1290  0.2354
#            2          NaN   0.1366  0.1110  0.1743
#            3          NaN   0.1317  0.0913  0.1778
#            4          NaN   0.1479  0.0962  0.1694
# SA    2021 1       0.2870   0.7380  0.4884  0.3669
#            2       0.1967   0.2860  0.2202  0.2881
#            3       0.1602   0.1728  0.1397  0.0036
#            4       0.1708   0.2201  0.1594  0.1968
#       2022 1       0.1843   0.2579  0.2197  0.0466
#            2       0.1670   0.2607  0.1926  0.0999
#            3       0.1710   0.2074  0.1343  0.0976
#            4       0.1624   0.2133  0.1876  0.1274
#       2023 1       0.1766   0.3284  0.2254  0.0336
#            2       0.2497   0.3744  0.2315  0.0000
#            3          NaN   0.2946  0.1916  0.0000
#            4          NaN   0.2946  0.1991  0.0000
#       2024 1          NaN   0.2540  0.1885  0.0504
#            2          NaN   0.3067  0.3809  0.0000
#            3          NaN   0.2079  0.3404  0.0000
#            4          NaN   0.4420  0.2829  0.0000
# VIC   2021 1       0.3671   1.0035  0.6306  0.3178
#            2       0.2277   0.4190  0.2774  0.5801
#            3       0.2037   0.3177  0.2237  0.3457
#            4       0.2128   0.3323  0.2278  0.3159
#       2022 1       0.2308   0.4401  0.2978  0.5521
#            2       0.2069   0.3952  0.2552  0.5294
#            3       0.2012   0.3818  0.2455  0.4388
#            4       0.2294   0.5463  0.3414  0.4522
#       2023 1       0.1865   0.4396  0.2785  0.3611
#            2       0.1651   0.3391  0.2081  0.2676
#            3          NaN   0.3446  0.2064  0.2673
#            4          NaN   0.4182  0.2487  0.4174
#       2024 1          NaN   0.3040  0.2030  0.0328
#            2          NaN   0.1994  0.1227  0.0348
#            3          NaN   0.1852  0.1123  0.0329
#            4          NaN   0.2008  0.1225  0.0334

# %% [markdown]
# ## Caps

# %%
cap_pivot = pd.pivot_table(raw_caps, index=["state", "year","quater"])
cap_pivot = cap_pivot.iloc[:,1:]
cap_pivot
# Out:
#                    annual  monthly   qtrly  weekly
# state year quater
# NSW   2021 1       0.8010   2.1827  1.4665  1.2431
#            2       0.4015   0.8848  0.5666  0.6856
#            3          NaN   0.3981  0.2766  0.4154
# QLD   2021 1       0.5837   1.6088  1.0546  1.2918
#            2       0.4263   0.4779  0.4647  0.0000
#            3          NaN   0.6248  0.6049  0.8465
# SA    2021 1       0.7067   2.1781  1.3240  0.3101
#            2       0.3279   0.8203  0.5078  0.0000
#            3          NaN   0.6221  0.3684  0.0000
# VIC   2021 1       0.9140   2.6548  1.6852  2.8248
#            2       0.3532   0.9807  0.6077  0.0000
#            3          NaN   0.6556  0.5572  0.1600

# %% [markdown]
# ## Strips

# %%
strips_pivot = pd.pivot_table(raw_strips, index=["state", "year","prod_type"])
strips_pivot = strips_pivot.iloc[:,1:]
strips_pivot
# Out:
#                       annual  monthly   qtrly  quater  weekly
# state year prod_type
# NSW   2021 Cal        0.1768   0.3026  0.2311       4  0.2020
#       2022 Cal        0.1326   0.1895  0.1558       4  0.2205
#            Fin        0.1529   0.2326  0.1821       2  0.2400
#       2023 Cal           NaN   0.1989  0.1397       4  0.1884
#            Fin        0.1200   0.1854  0.1373       2  0.1915
#       2024 Cal           NaN   0.0855  0.0663       4  0.0986
#            Fin           NaN   0.1573  0.1140       2  0.1798
# QLD   2021 Cal        0.1649   0.1549  0.1762       4  0.1312
#       2022 Cal        0.1256   0.1515  0.1335       4  0.2285
#            Fin        0.1424   0.1594  0.1510       2  0.2162
#       2023 Cal           NaN   0.1762  0.1274       4  0.2761
#            Fin        0.1248   0.1619  0.1276       2  0.2562
#       2024 Fin           NaN   0.1513  0.1096       2  0.2111
# SA    2021 Cal        0.1540   0.2870  0.2047       4  0.0852
#       2022 Cal        0.1381   0.2110  0.1569       4  0.0923
#            Fin        0.1285   0.1858  0.1474       2  0.1416
#       2023 Cal           NaN   0.2915  0.1874       4  0.0421
#            Fin        0.1415   0.2488  0.1635       2  0.0851
#       2024 Cal           NaN   0.2910  0.2440       4  0.0149
#            Fin           NaN   0.2605  0.1966       2  0.0161
# VIC   2021 Cal        0.2137   0.4406  0.2917       4  0.4260
#       2022 Cal        0.1836   0.3522  0.2365       4  0.4204
#            Fin        0.1919   0.3362  0.2320       2  0.4145
#       2023 Cal           NaN   0.3476  0.2194       4  0.2461
#            Fin        0.1533   0.3334  0.2155       2  0.2893
#       2024 Cal           NaN   0.2108  0.1350       4  0.0622
#            Fin           NaN   0.2563  0.1639       2  0.1084
